# %%
import pandas as pd
import numpy as np  
#from datetime import datetime
import altair as alt

# %%
from google.colab import drive  #needed to access a file on google drive
drive.mount('/content/gdrive')

csv_data = pd.read_csv("/content/gdrive/Shareddrives/Capstone697/Stub Code/hpt/hp_tuning_GBT.csv")
# Out:
# Mounted at /content/gdrive

# %%
csv_data
# Out:
#        Result                    model_param     Score   type  learning_rate  \
# 0    0.904420   0.025 / 200 / 3 / sqrt / 1.0  Accuracy  train          0.025
# 1    0.914425   0.025 / 250 / 3 / sqrt / 0.5  Accuracy  train          0.025
# 2    0.919205  0.025 / 250 / 3 / sqrt / 0.75  Accuracy  train          0.025
# 3    0.923387   0.025 / 250 / 3 / sqrt / 1.0  Accuracy  train          0.025
# 4    0.985962  0.025 / 200 / 5 / sqrt / 0.75  Accuracy  train          0.025
# ..        ...                            ...       ...    ...            ...
# 647  0.282609      0.2 / 50 / 3 / sqrt / 1.0        F1   test          0.200
# 648  0.333711      0.2 / 75 / 3 / sqrt / 0.5        F1   test          0.200
# 649  0.301181     0.2 / 75 / 3 / sqrt / 0.75        F1   test          0.200
# 650  0.320223      0.2 / 75 / 3 / sqrt / 1.0        F1   test          0.200
# 651  0.344907     0.2 / 100 / 3 / sqrt / 0.5        F1   test          0.200
#
# ...

# %%
### how many parameter iterations?
len(csv_data.model_param.unique())
# Out:
# 163

# %%
### look at the raw "messy" data
df = csv_data.copy()
df = df[df.Score=='F1']

chart = alt.Chart(df).mark_line().encode(
    x = 'model_param:O',
    y = 'Result:Q',
    color = 'type:N',

).properties(
    title = 'F1 Score'
)
chart
# Out:
# alt.Chart(...)

# %%
### look at the raw "messy" data
df = csv_data.copy()
df = df[df.Score=='Accuracy']

chart = alt.Chart(df).mark_line().encode(
    x = 'model_param:O',
    y = 'Result:Q',
    color = 'type:N',

).properties(
    title = 'Accuracy'
)
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# # Holding "all else equal" let's look at the median result for each parameter option to identify any trends...

# %%
df = csv_data.copy()
df = df[df.Score=='F1']
#print(df.columns)
df = df.groupby(['type','learning_rate',])['Result'].median().reset_index()

chart1 = alt.Chart(df).mark_line().encode(
    x = 'learning_rate:O',
    y = 'Result:Q',
    color = 'type:N',
    tooltip = 'learning_rate:Q',

).properties(
    title = 'F1 Score'
)

df = csv_data.copy()
df = df[df.Score=='F1']
df = df.groupby(['type','n_estimators',])['Result'].median().reset_index()


chart2 = alt.Chart(df).mark_line().encode(
    x = 'n_estimators:O',
    y = 'Result:Q',
    color = 'type:N',
    tooltip = 'n_estimators:Q',

).properties(
    title = 'F1 Score'
)

df = csv_data.copy()
df = df[df.Score=='F1']
#print(df.columns)
df = df.groupby(['type','max_depth',])['Result'].median().reset_index()
#display(df)

chart3 = alt.Chart(df).mark_line().encode(
    x = 'max_depth:O',
    y = 'Result:Q',
    color = 'type:N',
    tooltip = 'max_depth:Q',

).properties(
    title = 'F1 Score'
)

df = csv_data.copy()
df = df[df.Score=='F1']
#print(df.columns)
df = df.groupby(['type','max_features',])['Result'].median().reset_index()

chart4 = alt.Chart(df).mark_line().encode(
    x = 'max_features:O',
    y = 'Result:Q',
    color = 'type:N',
    tooltip = 'max_features:Q',

).properties(
    title = 'F1 Score'
)

df = csv_data.copy()
df = df[df.Score=='F1']
#print(df.columns)
df = df.groupby(['type','subsample',])['Result'].median().reset_index()

chart5 = alt.Chart(df).mark_line().encode(
    x = 'subsample:O',
    y = 'Result:Q',
    color = 'type:N',
    tooltip = 'subsample:Q',

).properties(
    title = 'F1 Score'
)

chart1 | chart2 | chart3 | chart4 | chart5
# Out:
# alt.HConcatChart(...)

# %%
df = csv_data.copy()
df = df[df.Score=='Accuracy']
#print(df.columns)
df = df.groupby(['type','learning_rate',])['Result'].median().reset_index()

chart1 = alt.Chart(df).mark_line().encode(
    x = 'learning_rate:O',
    y = 'Result:Q',
    color = 'type:N',
    tooltip = 'learning_rate:Q',

).properties(
    title = 'Accuracy'
)

df = csv_data.copy()
df = df[df.Score=='Accuracy']
df = df.groupby(['type','n_estimators',])['Result'].median().reset_index()


chart2 = alt.Chart(df).mark_line().encode(
    x = 'n_estimators:O',
    y = 'Result:Q',
    color = 'type:N',
    tooltip = 'n_estimators:Q',

).properties(
    title = 'Accuracy'
)

df = csv_data.copy()
df = df[df.Score=='Accuracy']
#print(df.columns)
df = df.groupby(['type','max_depth',])['Result'].median().reset_index()
#display(df)

chart3 = alt.Chart(df).mark_line().encode(
    x = 'max_depth:O',
    y = 'Result:Q',
    color = 'type:N',
    tooltip = 'max_depth:Q',

).properties(
    title = 'Accuracy'
)

df = csv_data.copy()
df = df[df.Score=='Accuracy']
#print(df.columns)
df = df.groupby(['type','max_features',])['Result'].median().reset_index()

chart4 = alt.Chart(df).mark_line().encode(
    x = 'max_features:O',
    y = 'Result:Q',
    color = 'type:N',
    tooltip = 'max_features:Q',

).properties(
    title = 'Accuracy'
)

df = csv_data.copy()
df = df[df.Score=='Accuracy']
#print(df.columns)
df = df.groupby(['type','subsample',])['Result'].median().reset_index()

chart5 = alt.Chart(df).mark_line().encode(
    x = 'subsample:O',
    y = 'Result:Q',
    color = 'type:N',
    tooltip = 'subsample:Q',

).properties(
    title = 'Accuracy'
)

chart1 | chart2 | chart3 | chart4 | chart5
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ## Notes

# %%
df = csv_data.copy()
df = df[(df.model_param=='0.15 / 100 / 3 / sqrt / 0.5') ]
df
# Out:
#        Result                  model_param     Score   type  learning_rate  \
# 139  0.971327  0.15 / 100 / 3 / sqrt / 0.5  Accuracy  train           0.15
# 302  0.794502  0.15 / 100 / 3 / sqrt / 0.5  Accuracy   test           0.15
# 465  0.930357  0.15 / 100 / 3 / sqrt / 0.5        F1  train           0.15
# 628  0.386420  0.15 / 100 / 3 / sqrt / 0.5        F1   test           0.15
#
#      n_estimators  max_depth max_features  subsample
# 139           100          3         sqrt        0.5
# 302           100          3         sqrt        0.5
# 465           100          3         sqrt        0.5
# 628           100          3         sqrt        0.5
